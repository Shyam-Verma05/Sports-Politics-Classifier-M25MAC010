# %% [markdown]
# # Model Comparison: Sports vs Politics Classification

# %%
from src.naive_bayes import run_naive_bayes
from src.logistic_regression import run_logistic_regression
from src.svm_model import run_svm

texts = open('../dataset/sports.txt').read().splitlines() + open('../dataset/politics.txt').read().splitlines()
labels = ['SPORTS']*10 + ['POLITICS']*10

run_naive_bayes(texts, labels)
run_logistic_regression(texts, labels)
run_svm(texts, labels)
